# %% [markdown]
# ### Run this ONLY ONCE in [colab](https://colab.research.google.com/github/nilakshdas/bmed8813rob-sp21-team1-r2drink2/blob/main/testing.ipynb)

# %%
# %%capture

! git clone https://github.com/nilakshdas/bmed8813rob-sp21-team1-r2drink2.git
! cd bmed8813rob-sp21-team1-r2drink2 && pip install -r requirements.txt

# %% [markdown]
# ### Run this EVERY TIME colab runtime is restarted

# %%
import sys; sys.path.append("/content/bmed8813rob-sp21-team1-r2drink2")

# %% [markdown]
# ### Code starts here

# %%
# %%capture

import numpy as np
from IPython.display import Image
from numpngw import write_apng

from r2drink2.env import render_env

# %%
frames = render_env(num_frames=10)

# %%
write_apng("output.png", np.uint8(frames), delay=100)
Image(filename="output.png")
